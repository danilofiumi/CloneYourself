# %%
# !git clone https://github.com/facefusion/facefusion
# Out:
# fatal: destination path 'facefusion' already exists and is not an empty directory.

# %%
# %cd facefusion
# Out:
# /datasets/_deepnote_work/facefusion

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 MB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 37.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 58.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 56.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.5/287.5 kB 14.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.7/431.7 kB 25.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 36.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 18.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 46.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# Update data and download os dependencies

# %%
# %mkdir data
# %mkdir out
# !apt-get update && apt-get install ffmpeg libsm6 libxext6  -y
# Out:
# mkdir: cannot create directory ‘data’: File exists
# mkdir: cannot create directory ‘out’: File exists
# Get:1 http://deb.debian.org/debian bullseye InRelease [116 kB]
# Get:2 http://deb.debian.org/debian-security bullseye-security InRelease [27.2 kB]
# Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.1 kB]
# Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8,066 kB]
# Get:5 http://deb.debian.org/debian-security bullseye-security/main amd64 Packages [363 kB]
# Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Packages [18.8 kB]
# Fetched 8,635 kB in 5s (1,846 kB/s)
#
#
#
#
# libsm6 is already the newest version (2:1.2.3-1).
# libsm6 set to manually installed.
# libxext6 is already the newest version (2:1.3.3-1.1).
# libxext6 set to manually installed.
# The following additional packages will be installed:
#   alsa-topology-conf alsa-ucm-conf i965-va-driver intel-media-va-driver
# ...

# %%
# !python facefusion.py headless-run --face-swapper-model ghost_2_256 -s data/selfie.jpeg -t data/UgcVideo.mp4 -o out/mytest1.mp4
# Out:
# [FACEFUSION.CORE] Processing step 1 of 1
# Analysing: 100%|===================| 434/434 [00:07<00:00, 59.30frame/s, rate=0]
# [FACEFUSION.CORE] Extracting frames with a resolution of 1080x1920 and 30.0 frames per second
# Extracting: 100%|==========================| 434/434 [00:52<00:00,  8.34frame/s]
# [FACEFUSION.FACE_SWAPPER] Processing
# Processing: 100%|=| 434/434 [19:44<00:00,  2.73s/frame, execution_providers=['cp
# [FACEFUSION.CORE] Merging video with a resolution of 1080x1920 and 30.0 frames per second
# Merging: 100%|=============================| 434/434 [00:49<00:00,  8.71frame/s]
# [FACEFUSION.CORE] Processing to video succeed in 1309.63 seconds

# %%
# !python facefusion.py headless-run --processors lip_syncer -s data/FinalClonedVoice.MP3 -t out/mytest1.mp4 -o out/final_output.mp4
# Out:
# [FACEFUSION.CORE] Processing step 1 of 1
# Downloading: 100%|=| 8.00/8.00 [00:00<00:00, 10.3B/s, download_providers=['githu
# Downloading: 100%|=| 138M/138M [00:07<00:00, 18.5MB/s, download_providers=['gith
# Analysing: 100%|===================| 434/434 [00:38<00:00, 11.41frame/s, rate=0]
# [FACEFUSION.CORE] Extracting frames with a resolution of 1080x1920 and 30.0 frames per second
# Extracting: 100%|==========================| 434/434 [01:42<00:00,  4.25frame/s]
# [FACEFUSION.LIP_SYNCER] Processing
# Processing: 100%|=| 434/434 [17:14<00:00,  2.38s/frame, execution_providers=['cp
# [FACEFUSION.CORE] Merging video with a resolution of 1080x1920 and 30.0 frames per second
# Merging: 100%|=============================| 434/434 [01:14<00:00,  5.82frame/s]
# [FACEFUSION.CORE] Processing to video succeed in 1339.24 seconds
